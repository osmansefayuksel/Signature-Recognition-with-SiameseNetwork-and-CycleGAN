# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2513, done.
# remote: Total 2513 (delta 0), reused 0 (delta 0), pack-reused 2513
# Receiving objects: 100% (2513/2513), 8.20 MiB | 18.99 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.

# %%
# !cd pytorch-CycleGAN-and-pix2pix/

# %%
# !pip install -r requirements.txt

# %%
# !pip install torch>=1.4.0

# %%
# !pip install torchvision>=0.5.0
# !pip install dominate>=2.4.0
# !pip install visdom>=0.1.8.8
# !pip install wandb

# %%
# !unzip /content/drive/MyDrive/signdata/trainA.zip
# !unzip /content/drive/MyDrive/signdata/trainB.zip
# !unzip /content/drive/MyDrive/signdata/testA.zip
# !unzip /content/drive/MyDrive/signdata/testB.zip

# %%
# !cd /content/pytorch-CycleGAN-and-pix2pix

# %%
# !python /content/pytorch-CycleGAN-and-pix2pix/train.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/datasets/signdata --name signdata --model cycle_gan

# %%
# !python /content/pytorch-CycleGAN-and-pix2pix/test.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/datasets/signdata/testB --name signdata --model test --no_dropout
